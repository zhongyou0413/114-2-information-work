# %% [markdown]
# <a href="https://colab.research.google.com/github/zhongyou0413/114-2-information-work/blob/main/2_1_%2C_2_2_%E8%B3%87%E6%96%99%E7%B5%90%E6%A7%8B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 2-1-1 陣列

# %%
#1 讀指定出指定編號的值、連續讀出所有值
arr = [88,92,96,86,95,83,97,91,85,99]
print(arr)
# Out:
# [88, 92, 96, 86, 95, 83, 97, 91, 85, 99]
# 83

# %%
#2 將arr分數加總，len() 取得陣列總長度
arr = [88,92,96,86,95,83,97,91,85,99]
sum=0
for i in range(5):
  sum = sum + i
print(sum)
# Out:
# 10

# %%
#3 z333 輸出每個月的值
cat = [3.2, 3.5, 3.8, 3.1, 3.3, 3.6]

# %%
#4 z334 取平均體重
cat = [3.2, 3.5, 3.8, 3.1, 3.3, 3.6]

# %%
#4 進階 說出月份與體重
cat = [3.2, 3.5, 3.8, 3.1, 3.3, 3.6]
month = ['一月','二月','三月','四月','五月','六月']
print('month陣列 的體重 cat陣列 公斤')

# %%
#6補充 是否存在 if ... in 陣列
items = ['道具A','道具B','道具C']
if '目標' in items:
  print('有')
else:
  print('沒有')

# %%
#7補充 是否存在 if ... in 陣列
month = int(input())
if month in [1,3]:
  print('31天')
elif month in [4,6]:
  print('30天')
elif month == 2:
  print('28天')
else:
  print('輸入錯誤')

# %% [markdown]
# ### 進階練習

# %%
#進階練習1 找最大最小值
#7
numbers = [23, 5, 71, 12, 9, 45]
max_val=0
min_val=0
print(f"陣列：{numbers}")
print(f"最大值：{max_val}")
print(f"最小值：{min_val}")

# %%
#進階練習2 檢查陣列中某兩數字相加等於target (雙迴圈)
nums = [2, 7, 16, 15, 11]
target = 18

# %%
#進階練習3 二維陣列 矩陣轉置 n*m 轉成 m*n (雙迴圈)
matrix = [
    [1, 2, 3],
    [4, 5, 6]
]

# %% [markdown]
# ## 2-1-2 堆疊

# %%
#1 堆疊LIFO 新增append() 與 彈出pop()
stack=[]
stack.append(10)  #放入10
  #放入20
  #放入30
print(stack)

# %%
#2 堆疊LIFO 彈出pop()
stack=[10,20,30,40,50]
print()  #彈出疊在最上面的值pop() (陣列最後面的值)
t = 0  #取得最上面的值pop()   (陣列最後面的值)
print(stack,t)
# Out:
# [] 10

# %%
#3 回上一頁
stack=[]
stack.append('網頁A')
stack.append('網頁B')
stack.append('網頁C')
stack.append('網頁D')
print('Stack',stack)
while ??? : #stack還有值
  print('Pop:', )#
print('堆疊已空')

# %%
#4 還原輸入
# 1. 建立一個空的堆疊來存放「輸入歷史紀錄」
history = []
# 2. 模擬輸入過程
history.append("輸入了：今天天氣不錯")
history.append("輸入了：準備來學 Python")
history.append("輸入了：堆疊真的很簡單")
print("目前紀錄:", history)
print("-" * 20)

# 3. 當輸入z，則會執行還原
# 請補齊 while內程式
while input() == 'z':
    ###############執行
    print("剩餘紀錄:", history)
print("程式結束")

# %% [markdown]
# ### 進階練習

# %%
#4 進階練習 將輸入的字串顛倒

# 準備資料
input_str = input() #輸入文字
stack = []

# 步驟 1：將字串中的每個字元依序放入 (append) 堆疊
for text in input_str:
    #??
    print('目前文字:',stack)

print("-" * 20)

# 步驟 2：當堆疊內還有東西時，依序彈出 (pop) 並組合
reversed_str = ""
while len(stack) > 0:
    #?
    #?
    print('剩餘堆疊:',stack,'反轉文字:',reversed_str)

# 印出結果
print("-" * 20)
print(f"原始字串: {input_str}")
print(f"反轉後: {reversed_str}")

# %% [markdown]
# ## 2-1-3 佇列

# %%
#1
queue=[]
queue.append(10)  #放入10
queue.append(20)  #放入20
queue.append(30)  #放入30
print(queue)
queue.pop(0) #從最前面取出
t= queue.pop(0) #從最前面取出
print(queue,t)

# %% [markdown]
# ## 2-2-1 進階的資料結構-樹

# %%
#1 樹、二元搜尋樹

# %% [markdown]
# ## 2-2-2 圖

# %%
#1 圖、圖的表示法
